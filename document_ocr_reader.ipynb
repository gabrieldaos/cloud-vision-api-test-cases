# %% [markdown]
# # Google Vision API Document Text Reader Test

# %%
# !pip install google-cloud-vision

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="mago-gv.json"

# %%
from IPython.display import Image
Image(filename='payment-agreement-template.png')

# %%
from google.cloud import vision
import io
client = vision.ImageAnnotatorClient()

with io.open('payment-agreement-template.png', 'rb') as image_file:
    content = image_file.read()

image = vision.types.Image(content=content)

response = client.text_detection(image=image)
texts = response.text_annotations

# %%
for text in texts:
        print('\n"{}"'.format(text.description))
# Out:
# "Payment Agreement
# KNOW ALL MEN BY THESE PRESENTS:
# This Contract is entered by and between:
# Janet Weldon, of legal age, Married, U.S., whose principal place of
# address is at 3080 Vesta Drive. Lynn Street, Oakland, California,
# 3508, (hereinafter referred to as "DEBTOR"):
# - and -
# David Lyke, of legal age, Single, U.S. whose principal place of
# address is at 731 Simpson Avenue Clay Lick Road San Jose,
# California, 67642, (hereinafter referred to as "CREDITOR):
# WITNESSETH: That -
# WHEREAS, the DEBTOR has an existing obligation to the creditor for an amount of $
# 3,000.00,
# WHEREAS, the DEBTOR and the CREDITOR, by the goodwill of both parties, desire to
# secure the amount of debt by entering into a new agreement whereby the sum of $
# 3,000.00 shall be set into structured payment agreement to the terms and conditions
# herein provided
# NOW, THEREFORE, for and in consideration of the foregoing premises, the parties
# hereto agree as follows:
# ...
